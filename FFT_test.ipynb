# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorPetch/Baby-Cry/blob/master/FFT_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !wget https://github.com/AllenDowney/ThinkDSP/archive/master.zip
# !unzip master.zip
# !ls ThinkDSP-master/code/
# !mv ThinkDSP-master/code/thinkdsp.py /content
# !mv ThinkDSP-master/code/thinkplot.py /content
# !ls /content/
# !rm wget-log.2
# !pip install ipywidgets
import thinkdsp
# Out:
# --2018-10-29 20:49:14--  https://github.com/AllenDowney/ThinkDSP/archive/master.zip
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/AllenDowney/ThinkDSP/zip/master [following]
# --2018-10-29 20:49:14--  https://codeload.github.com/AllenDowney/ThinkDSP/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.253.120, 192.30.253.121
# Connecting to codeload.github.com (codeload.github.com)|192.30.253.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [                 <=>]  71.60M  12.7MB/s    in 5.6s
#
# 2018-10-29 20:49:22 (12.7 MB/s) - ‘master.zip’ saved [75076244]
#
# Archive:  master.zip
# 6595d6fa413d68ae8ba8fbaf0b1f9a2e57460818
#    creating: ThinkDSP-master/
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
import matplotlib.pyplot as plt
import thinkdsp

Audio = thinkdsp.read_wave('Hunger00')
Audio.plot()
#Spectrum = Audio.make_spectrum()
#Spectrum.plot()
#thinkdsp.read_wave('Hunger00').make_spectrum().plot(4000)

# %%
thinkdsp.read_wave('Cold_Hot02.wav').plot()

# %%
print(thinkdsp.read_wave('Hunger-18.wav').make_spectrum().peaks())
# Out:
# [(416.7628543436343, 858.9939024390244), (396.16944489490237, 858.8414634146342), (368.59874770944873, 859.1463414634146), (366.74849738147657, 859.451219512195), (363.4959987034099, 858.6890243902438), (348.65619221754366, 876.0670731707316), (346.9605616458484, 859.6036585365854), (342.74969814988435, 859.2987804878048), (340.1090054991956, 860.9756097560976), (335.892709080205, 876.9817073170732), (331.5830424050837, 875.9146341463414), (331.4357186184331, 862.6524390243902), (331.1774949180235, 876.8292682926829), (329.5593937699884, 862.3475609756098), (327.65094185490614, 862.5), (326.7203263898114, 859.7560975609756), (324.8942989727228, 880.030487804878), (324.8737467157968, 860.8231707317073), (321.36782648314374, 861.1280487804878), (318.2991148447578, 896.951219512195), (317.9253109220091, 862.1951219512194), (313.5291798187602, 861.280487804878), (313.1964224841767, 877.1341463414634), (308.2644489966056, 858.5365853658536), (307.16408739892603, 862.0426829268292), (306.6
# ...

# %%
thinkdsp.read_wave('Hunger-18.wav').make_spectrum().plot(4000)

# %%
#thinkdsp.read_wave('Tired06.wav').make_spectrum().plot(4000)
#1,2,3,8,10,11,12,13,14

thisdict =	{
  0: "Hunger-18.wav",
  1: "Hunger-19.wav",
  2: "Hunger-20.wav",
  3: "Hunger-21.wav",
  4: "Hunger-22.wav",
  6: "Hunger-23.wav",
  7: "Hunger-24.wav",
  8: "Hunger-25.wav",
  9: "Hunger-26.wav",
  10:"Hunger-27.wav",
  11:"Hunger-28.wav",
  12:"Hunger-29.wav",
  13:"Hunger-30.wav",
  14:"Hunger-31.wav",
  15:"Hunger-32.wav",
  16:"Hunger-33.wav",
  17:"Hunger-34.wav",
  18:"Hunger-35.wav",
  19:"Hunger-36.wav",
  20:"Hunger-37.wav",
  21:"Hunger-38.wav"

    
}

j = 0
Temp1 = list()
Temp2 = list()
for x in thisdict:
  
  Temp = thinkdsp.read_wave(thisdict[x]).make_spectrum().peaks()
  
  for i in range(0,20):
    Temp1.append(Temp[i][1]) 
  print(Temp1)
    
  #print(j)
  if(j<len(thisdict)-1):
    del Temp1[:]
  j =j+1
# Out:
# [858.9939024390244, 858.8414634146342, 859.1463414634146, 859.451219512195, 858.6890243902438, 876.0670731707316, 859.6036585365854, 859.2987804878048, 860.9756097560976, 876.9817073170732, 875.9146341463414, 862.6524390243902, 876.8292682926829, 862.3475609756098, 862.5, 859.7560975609756, 880.030487804878, 860.8231707317073, 861.1280487804878, 896.951219512195]
# [1262.874251497006, 1261.5269461077846, 1259.5808383233534, 624.2514970059881, 1268.8622754491018, 623.502994011976, 1297.005988023952, 613.0239520958085, 1245.5089820359283, 1268.2634730538923, 623.3532934131737, 1291.1676646706587, 1288.922155688623, 1299.251497005988, 633.682634730539, 1244.1616766467066, 1266.7664670658685, 1273.2035928143714, 690.7185628742516, 625.1497005988025]
# ...

# %%
#thinkdsp.read_wave('Tired06.wav').make_spectrum().plot(4000)
#1,2,3,8,10,11,12,13,14

thisdict =	{
  0: "Cold_Hot00.wav",
  1: "Cold_Hot01.wav",
  2: "Cold_Hot02.wav",
  3: "Cold_Hot03.wav",
  4: "Cold_Hot04.wav",
  6: "Cold_Hot05.wav",
  7: "Cold_Hot06.wav",
  8: "Cold_Hot07.wav",
  9: "Lonely-08.wav",
  10:"Lonely-14.wav",
  11:"LowCry00.wav",
  12:"LowCry01.wav"
  
    
}

j = 0
Temp1 = list()
Temp2 = list()
for x in thisdict:
  
  Temp = thinkdsp.read_wave(thisdict[x]).make_spectrum().peaks()
  
  for i in range(0,20):
    Temp1.append(Temp[i][1]) 
  print(Temp1)
    
  #print(j)
  if(j<len(thisdict)-1):
    del Temp1[:]
  j =j+1

# %%
#thinkdsp.read_wave('Tired06.wav').make_spectrum().plot(4000)
#1,2,3,8,10,11,12,13,14

thisdict =	{
  0: "BellyPain00.wav",
  1: "BellyPain03.wav",
  2: "BellyPain04.wav",
  3: "BellyPain07.wav",
  4: "Hunger-05.wav",
  6: "Hunger-10.wav",
  7: "Hunger-12.wav",
  8: "Hunger-18.wav",
  9: "Hunger-19.wav",
  10:"Hunger-20.wav",
  11:"Hunger-22.wav",
  12:"Hunger-23.wav",
  13:"Hunger-24.wav",
  14:"Hunger-25.wav",
  15:"Hunger-26.wav",
  16:"Hunger-27.wav"
  
    
}

j = 0
Temp1 = list()
Temp2 = list()
for x in thisdict:
  
  Temp = thinkdsp.read_wave(thisdict[x]).make_spectrum().peaks()
  
  for i in range(0,20):
    Temp1.append(Temp[i][1]) 
  print(Temp1)
    
  #print(j)
  if(j<len(thisdict)-1):
    del Temp1[:]
  j =j+1

# %%
#thinkdsp.read_wave('Hunger05.wav').make_spectrum().plot(4000)
Hunger00 = thinkdsp.read_wave('Hunger00').make_dct()
Hunger01 = thinkdsp.read_wave('Hunger01.wav').make_dct()
Hunger02 = thinkdsp.read_wave('Hunger02.wav').make_dct()
Hunger03 = thinkdsp.read_wave('Hunger03.wav').make_dct()
Hunger04 = thinkdsp.read_wave('Hunger04.wav').make_dct()
Hunger05 = thinkdsp.read_wave('Hunger05.wav')
Hunger06 = thinkdsp.read_wave('Hunger06.wav').make_dct()
ColdHot00 = thinkdsp.read_wave('Cold_Hot06.wav')

# %%
wave = thinkdsp.read_wave('Hunger06.wav')
wave.__init__(thinkdsp.read_wave('Hunger06.wav'), framerate = 1000)
Hunger05.normalize(amp = 100)
ColdHot00.normalize(amp = 100)
x = ColdHot00.make_spectrum().peaks()
print(x[:20])

# %%
blabla = [(1,2), (3,2), (1,1), (2,2)]
sisim = blabla[0:3]
haha = list()
plspls = list()

for i in range(0,3):
    haha.append(blabla[i][1])
print(haha)
plspls.insert(0,haha)
#print("plspls:",plspls)
#print("Haha1:",haha)
#haha = sisim[0][1], sisim[1][1], sisim[2][1]
#print("Haha2:",haha)
print(plspls)

# %%
import numpy as np
from scipy.spatial.distance import euclidean

from fastdtw import fastdtw
x[:] = thinkdsp.read_wave('Cold_Hot01.wav').peaks()
y = thinkdsp.read_wave('Hunger02.wav').peaks()


z = x[:10]
w = y[:10]
print(w)
distance, path = fastdtw(z, w, dist=euclidean)
distance

# %%
x[1] = [(1,2),(2,3),(3,4)]
print(x)
